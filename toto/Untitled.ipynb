# %%
import os

import matplotlib
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
import torch

from data.util.dataset import MaskedTimeseries
from inference.forecaster import TotoForecaster
from model.toto import Toto

# These lines make gpu execution in CUDA deterministic
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"
torch.use_deterministic_algorithms(True)
# Out:
# /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages/lightning/fabric/__init__.py:40: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages/gluonts/json.py:102: UserWarning: Using `json`-module for json-handling. Consider installing one of `orjson`, `ujson` to speed up serialization and deserialization.
#   warnings.warn(

# %%
pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: torch==2.7.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 1)) (2.7.0)
# Requirement already satisfied: aioboto3==12.4.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 2)) (12.4.0)
# Requirement already satisfied: beartype==0.18.5 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 3)) (0.18.5)
# Requirement already satisfied: boto3==1.34.69 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 4)) (1.34.69)
# Requirement already satisfied: datasets==2.17.1 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 5)) (2.17.1)
# Requirement already satisfied: dill==0.3.8 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 6)) (0.3.8)
# Requirement already satisfied: einops==0.7.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: gluonts==0.15.1 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from gluonts[torch]==0.15.1->-r ../requirements.txt (line 8)) (0.15.1)
# Requirement already satisfied: jaxtyping==0.2.29 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 9)) (0.2.29)
# Requirement already satisfied: mypy==1.11.1 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 10)) (1.11.1)
# Requirement already satisfied: pandas==2.2.3 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 11)) (2.2.3)
# Requirement already satisfied: pytest==8.3.5 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 12)) (8.3.5)
# Requirement already satisfied: pytest-env==1.1.5 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 13)) (1.1.5)
# Requirement already satisfied: rotary-embedding-torch==0.8.6 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 14)) (0.8.6)
# Requirement already satisfied: scikit-learn==1.5.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 15)) (1.5.0)
# Requirement already satisfied: types-tabulate==0.9.0.20241207 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 16)) (0.9.0.20241207)
# Requirement already satisfied: transformers==4.50.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 17)) (4.50.0)
# Requirement already satisfied: tqdm==4.66.3 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 18)) (4.66.3)
# Requirement already satisfied: pyyaml==6.0.2 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 21)) (6.0.2)
# Requirement already satisfied: types-PyYAML==6.0.12.20240917 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 22)) (6.0.12.20240917)
# Requirement already satisfied: black==24.10.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 23)) (24.10.0)
# Requirement already satisfied: isort==5.13.2 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 24)) (5.13.2)
# Requirement already satisfied: jupyter==1.1.1 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 26)) (1.1.1)
# Requirement already satisfied: matplotlib==3.9.2 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 27)) (3.9.2)
# Requirement already satisfied: tabulate==0.9.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from -r ../requirements.txt (line 28)) (0.9.0)
# Requirement already satisfied: filelock in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from torch==2.7.0->-r ../requirements.txt (line 1)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from torch==2.7.0->-r ../requirements.txt (line 1)) (4.14.0)
# Requirement already satisfied: setuptools in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from torch==2.7.0->-r ../requirements.txt (line 1)) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from torch==2.7.0->-r ../requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from torch==2.7.0->-r ../requirements.txt (line 1)) (3.5)
# Requirement already satisfied: jinja2 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from torch==2.7.0->-r ../requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from torch==2.7.0->-r ../requirements.txt (line 1)) (2023.10.0)
# Requirement already satisfied: aiobotocore==2.12.3 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from aiobotocore[boto3]==2.12.3->aioboto3==12.4.0->-r ../requirements.txt (line 2)) (2.12.3)
# Requirement already satisfied: botocore<1.35.0,>=1.34.69 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from boto3==1.34.69->-r ../requirements.txt (line 4)) (1.34.69)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from boto3==1.34.69->-r ../requirements.txt (line 4)) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from boto3==1.34.69->-r ../requirements.txt (line 4)) (0.10.4)
# Requirement already satisfied: numpy>=1.17 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from datasets==2.17.1->-r ../requirements.txt (line 5)) (1.26.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from datasets==2.17.1->-r ../requirements.txt (line 5)) (20.0.0)
# Requirement already satisfied: pyarrow-hotfix in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from datasets==2.17.1->-r ../requirements.txt (line 5)) (0.7)
# Requirement already satisfied: requests>=2.19.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from datasets==2.17.1->-r ../requirements.txt (line 5)) (2.32.3)
# Requirement already satisfied: xxhash in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from datasets==2.17.1->-r ../requirements.txt (line 5)) (3.5.0)
# Requirement already satisfied: multiprocess in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from datasets==2.17.1->-r ../requirements.txt (line 5)) (0.70.16)
# Requirement already satisfied: aiohttp in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from datasets==2.17.1->-r ../requirements.txt (line 5)) (3.12.11)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from datasets==2.17.1->-r ../requirements.txt (line 5)) (0.32.4)
# Requirement already satisfied: packaging in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from datasets==2.17.1->-r ../requirements.txt (line 5)) (24.2)
# Requirement already satisfied: pydantic<3,>=1.7 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from gluonts==0.15.1->gluonts[torch]==0.15.1->-r ../requirements.txt (line 8)) (2.11.5)
# Requirement already satisfied: toolz~=0.10 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from gluonts==0.15.1->gluonts[torch]==0.15.1->-r ../requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from pandas==2.2.3->-r ../requirements.txt (line 11)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from pandas==2.2.3->-r ../requirements.txt (line 11)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from pandas==2.2.3->-r ../requirements.txt (line 11)) (2025.2)
# Requirement already satisfied: typeguard==2.13.3 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jaxtyping==0.2.29->-r ../requirements.txt (line 9)) (2.13.3)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from mypy==1.11.1->-r ../requirements.txt (line 10)) (1.1.0)
# Requirement already satisfied: iniconfig in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from pytest==8.3.5->-r ../requirements.txt (line 12)) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from pytest==8.3.5->-r ../requirements.txt (line 12)) (1.6.0)
# Requirement already satisfied: scipy>=1.6.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from scikit-learn==1.5.0->-r ../requirements.txt (line 15)) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from scikit-learn==1.5.0->-r ../requirements.txt (line 15)) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from scikit-learn==1.5.0->-r ../requirements.txt (line 15)) (3.6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from transformers==4.50.0->-r ../requirements.txt (line 17)) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from transformers==4.50.0->-r ../requirements.txt (line 17)) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from transformers==4.50.0->-r ../requirements.txt (line 17)) (0.5.3)
# Requirement already satisfied: click>=8.0.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from black==24.10.0->-r ../requirements.txt (line 23)) (8.2.1)
# Requirement already satisfied: pathspec>=0.9.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from black==24.10.0->-r ../requirements.txt (line 23)) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from black==24.10.0->-r ../requirements.txt (line 23)) (4.3.8)
# Requirement already satisfied: notebook in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyter==1.1.1->-r ../requirements.txt (line 26)) (7.4.3)
# Requirement already satisfied: jupyter-console in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyter==1.1.1->-r ../requirements.txt (line 26)) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyter==1.1.1->-r ../requirements.txt (line 26)) (7.16.6)
# Requirement already satisfied: ipykernel in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyter==1.1.1->-r ../requirements.txt (line 26)) (6.29.5)
# Requirement already satisfied: ipywidgets in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyter==1.1.1->-r ../requirements.txt (line 26)) (8.1.7)
# Requirement already satisfied: jupyterlab in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyter==1.1.1->-r ../requirements.txt (line 26)) (4.4.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 27)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 27)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 27)) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 27)) (1.4.8)
# Requirement already satisfied: pillow>=8 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 27)) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 27)) (3.2.3)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from aiobotocore==2.12.3->aiobotocore[boto3]==2.12.3->aioboto3==12.4.0->-r ../requirements.txt (line 2)) (1.17.2)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from aiobotocore==2.12.3->aiobotocore[boto3]==2.12.3->aioboto3==12.4.0->-r ../requirements.txt (line 2)) (0.12.0)
# Requirement already satisfied: lightning<2.2,>=2.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from gluonts[torch]==0.15.1->-r ../requirements.txt (line 8)) (2.1.4)
# Requirement already satisfied: pytorch-lightning<2.2,>=2.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from gluonts[torch]==0.15.1->-r ../requirements.txt (line 8)) (2.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from aiohttp->datasets==2.17.1->-r ../requirements.txt (line 5)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from aiohttp->datasets==2.17.1->-r ../requirements.txt (line 5)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from aiohttp->datasets==2.17.1->-r ../requirements.txt (line 5)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from aiohttp->datasets==2.17.1->-r ../requirements.txt (line 5)) (1.6.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from aiohttp->datasets==2.17.1->-r ../requirements.txt (line 5)) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from aiohttp->datasets==2.17.1->-r ../requirements.txt (line 5)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from aiohttp->datasets==2.17.1->-r ../requirements.txt (line 5)) (1.20.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from botocore<1.35.0,>=1.34.69->boto3==1.34.69->-r ../requirements.txt (line 4)) (2.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from huggingface-hub>=0.19.4->datasets==2.17.1->-r ../requirements.txt (line 5)) (1.1.3)
# Requirement already satisfied: lightning-utilities<2.0,>=0.8.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from lightning<2.2,>=2.0->gluonts[torch]==0.15.1->-r ../requirements.txt (line 8)) (0.14.3)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from lightning<2.2,>=2.0->gluonts[torch]==0.15.1->-r ../requirements.txt (line 8)) (1.7.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from pydantic<3,>=1.7->gluonts==0.15.1->gluonts[torch]==0.15.1->-r ../requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from pydantic<3,>=1.7->gluonts==0.15.1->gluonts[torch]==0.15.1->-r ../requirements.txt (line 8)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from pydantic<3,>=1.7->gluonts==0.15.1->gluonts[torch]==0.15.1->-r ../requirements.txt (line 8)) (0.4.1)
# Requirement already satisfied: six>=1.5 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas==2.2.3->-r ../requirements.txt (line 11)) (1.17.0)
# Requirement already satisfied: idna>=2.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from yarl<2.0,>=1.17.0->aiohttp->datasets==2.17.1->-r ../requirements.txt (line 5)) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from requests>=2.19.0->datasets==2.17.1->-r ../requirements.txt (line 5)) (3.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from requests>=2.19.0->datasets==2.17.1->-r ../requirements.txt (line 5)) (2025.4.26)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from sympy>=1.13.3->torch==2.7.0->-r ../requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: appnope in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (9.3.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (1.6.0)
# Requirement already satisfied: psutil in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (26.4.0)
# Requirement already satisfied: tornado>=6.1 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (5.14.3)
# Requirement already satisfied: decorator in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (2.19.1)
# Requirement already satisfied: stack_data in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.7.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from ipywidgets->jupyter==1.1.1->-r ../requirements.txt (line 26)) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from ipywidgets->jupyter==1.1.1->-r ../requirements.txt (line 26)) (3.0.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jinja2->torch==2.7.0->-r ../requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.2.4)
# Requirement already satisfied: anyio>=3.1.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.22.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (4.24.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (21.2.0)
# Requirement already satisfied: httpcore==1.* in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from httpx>=0.25.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.25.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (3.3.0)
# Requirement already satisfied: rfc3339-validator in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.1.1)
# Requirement already satisfied: fqdn in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (1.5.1)
# Requirement already satisfied: isoduration in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (3.0.0)
# Requirement already satisfied: uri-template in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from nbconvert->jupyter==1.1.1->-r ../requirements.txt (line 26)) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1->-r ../requirements.txt (line 26)) (6.2.0)
# Requirement already satisfied: defusedxml in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from nbconvert->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from nbconvert->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from nbconvert->jupyter==1.1.1->-r ../requirements.txt (line 26)) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from nbconvert->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from nbconvert->jupyter==1.1.1->-r ../requirements.txt (line 26)) (1.5.1)
# Requirement already satisfied: webencodings in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1->-r ../requirements.txt (line 26)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (2.21.1)
# Requirement already satisfied: cffi>=1.0.1 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (1.17.1)
# Requirement already satisfied: pycparser in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (2.22)
# Requirement already satisfied: soupsieve>1.2 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from beautifulsoup4->nbconvert->jupyter==1.1.1->-r ../requirements.txt (line 26)) (2.7)
# Requirement already satisfied: arrow>=0.15.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r ../requirements.txt (line 26)) (2.9.0.20250516)
# Requirement already satisfied: executing>=1.2.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/ozymandias/work/frc-agent/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r ../requirements.txt (line 26)) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
ETT_LOCAL_PATH = "/Users/ozymandias/work/frc-agent/ETDataset/ETT-small"

# %%
df = (
    pd.read_csv(f"{ETT_LOCAL_PATH}/ETTm1.csv")
    .assign(date=lambda df: pd.to_datetime(df["date"]))
    .assign(timestamp_seconds=lambda df: (df.date - pd.Timestamp("1970-01-01")) // pd.Timedelta('1s'))
)

df
# Out:
#                      date    HUFL   HULL   MUFL   MULL   LUFL   LULL  \
# 0     2016-07-01 00:00:00   5.827  2.009  1.599  0.462  4.203  1.340
# 1     2016-07-01 00:15:00   5.760  2.076  1.492  0.426  4.264  1.401
# 2     2016-07-01 00:30:00   5.760  1.942  1.492  0.391  4.234  1.310
# 3     2016-07-01 00:45:00   5.760  1.942  1.492  0.426  4.234  1.310
# 4     2016-07-01 01:00:00   5.693  2.076  1.492  0.426  4.142  1.371
# ...                   ...     ...    ...    ...    ...    ...    ...
# 69675 2018-06-26 18:45:00   9.310  3.550  5.437  1.670  3.868  1.462
# 69676 2018-06-26 19:00:00  10.114  3.550  6.183  1.564  3.716  1.462
# 69677 2018-06-26 19:15:00  10.784  3.349  7.000  1.635  3.746  1.432
# 69678 2018-06-26 19:30:00  11.655  3.617  7.533  1.706  4.173  1.523
# 69679 2018-06-26 19:45:00  12.994  3.818  8.244  1.777  4.721  1.523
#
#               OT  timestamp_seconds
# 0      30.531000         1467331200
# 1      30.459999         1467332100
# 2      30.038000         1467333000
# 3      27.013000         1467333900
# 4      27.787001         1467334800
# ...          ...                ...
# 69675   9.567000         1530038700
# 69676   9.567000         1530039600
# 69677   9.426000         1530040500
# 69678   9.426000         1530041400
# 69679   9.778000         1530042300
#
# [69680 rows x 9 columns]

# %%
context_length = 4096
prediction_length = 336

# %%
feature_columns = ["HUFL", "HULL", "MUFL", "MULL", "LUFL", "LULL", "OT"]
n_variates = len(feature_columns)
interval = 60 * 15  # 15-min intervals
input_df = df.iloc[-(context_length+prediction_length):-prediction_length]
target_df = df.iloc[-prediction_length:]
DEVICE = "cuda"

input_series = torch.from_numpy(input_df[feature_columns].values.T).to(torch.float).to(DEVICE)
input_series.shape
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[7], line 8
#       5 target_df = df.iloc[-prediction_length:]
#       6 DEVICE = "cuda"
# ----> 8 input_series = torch.from_numpy(input_df[feature_columns].values.T).to(torch.float).to(DEVICE)
#       9 input_series.shape
#
# File ~/work/frc-agent/lib/python3.13/site-packages/torch/cuda/__init__.py:363, in _lazy_init()
#     358     raise RuntimeError(
#     359         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     360         "multiprocessing, you must use the 'spawn' start method"
#     361     )
#     362 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 363     raise AssertionError("Torch not compiled with CUDA enabled")
#     364 if _cudart is None:
#     365     raise AssertionError(
#     366         "libcudart functions unavailable. It looks like you have a broken build?"
#     367     )
#
# AssertionError: Torch not compiled with CUDA enabled
